# %%
#Import the necessary modules
from astropy import units as u
from astropy.coordinates import SkyCoord
from astropy.wcs import WCS
import warnings
import numpy as np
warnings.filterwarnings('ignore')
from astroquery.vizier import Vizier
from astroquery.gaia import Gaia
from astroquery.simbad import Simbad
# %matplotlib inline
import matplotlib.pyplot as plt
from IPython.display import Image
from IPython.core.display import HTML
import pandas as pd
# Out:
# Created TAP+ (v1.2.1) - Connection:
# 	Host: gea.esac.esa.int
# 	Use HTTPS: True
# 	Port: 443
# 	SSL Port: 443
# Created TAP+ (v1.2.1) - Connection:
# 	Host: geadata.esac.esa.int
# 	Use HTTPS: True
# 	Port: 443
# 	SSL Port: 443
# Bad key "text.kerning_factor" on line 4 in
# /home/ariggonz/anaconda3/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test_patch.mplstyle.
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.1.3/matplotlibrc.template
# or from the matplotlib source distribution

# %%
c=SkyCoord("11 02 24.8763629208 -77 33 35.667131796", unit=(u.hourangle, u.deg))
c
# Out:
# <SkyCoord (ICRS): (ra, dec) in deg
#     (165.60365151, -77.55990754)>

# %%
c.ra.deg
# Out:
# 165.60365151217

# %%
#Gaia.ROW_LIMIT = -1
Vizier.ROW_LIMIT=-1

# %%
result = Vizier.query_region(SkyCoord(ra=c.ra.deg, dec=c.dec.deg,unit=(u.degree, u.degree), frame='icrs'),
                            radius=u.Quantity(1,u.deg),
                             catalog=["I/355/gaiadr3"]
                            )
result #"B/wds",
# Out:
# TableList with 1 tables:
# 	'0:I/355/gaiadr3' with 57 column(s) and 70540 row(s)

# %%
print(result[0])
# Out:
#     RA_ICRS         DE_ICRS     ...     RAJ2000         DEJ2000
#       deg             deg       ...       deg             deg
# --------------- --------------- ... --------------- ---------------
# 168.75168777885 -78.31091363388 ... 168.75173961377 -78.31092927347
# 168.75144148035 -78.29951110747 ... 168.75159217725 -78.29950794769
# 168.74499183521 -78.29737626754 ... 168.74502873489 -78.29738231302
# 168.73843185821 -78.29828521421 ... 168.73859715055 -78.29831223165
# 168.78001972943 -78.30270608670 ... 168.78028885344 -78.30271077213
# 168.81019542346 -78.29694418301 ... 168.81045632377 -78.29694581975
# 168.79738110903 -78.29467086570 ... 168.79751229292 -78.29466746458
# 168.77083769339 -78.29162159054 ... 168.77099018012 -78.29164557933
# 168.94329410058 -78.27443078046 ... 168.94335034547 -78.27443758394
# 168.96307284269 -78.26393752661 ... 168.96322263143 -78.26395198526
#             ...             ... ...             ...             ...
# ...

# %%
result[0]["Gmag"]
# Out:
# <MaskedColumn name='Gmag' dtype='float64' unit='mag' format='{:9.6f}' description='? G-band mean magnitude (phot_g_mean_mag)' length=70540>
# 19.801567
# 18.921015
# 18.737949
# 19.341915
# 14.707193
# 18.009581
# 19.363621
# 17.052366
# 13.030743
# 19.227770
# 17.672129
# 19.953171
#       ...
# 19.291105
# 19.161747
# 21.019266
# 20.658922
# 20.891773
# 21.125593
# 16.542984
# 17.407238
# 18.451040
# 17.154919
# 17.915689
# 18.219275

# %%
cond_gaia=(result[0]["RUWE"]<1.2)&(result[0]["Gmag"]<19)

print(result[0][cond_gaia])
# Out:
#     RA_ICRS         DE_ICRS     ...     RAJ2000         DEJ2000
#       deg             deg       ...       deg             deg
# --------------- --------------- ... --------------- ---------------
# 168.75144148035 -78.29951110747 ... 168.75159217725 -78.29950794769
# 168.74499183521 -78.29737626754 ... 168.74502873489 -78.29738231302
# 168.78001972943 -78.30270608670 ... 168.78028885344 -78.30271077213
# 168.81019542346 -78.29694418301 ... 168.81045632377 -78.29694581975
# 168.77083769339 -78.29162159054 ... 168.77099018012 -78.29164557933
# 168.94329410058 -78.27443078046 ... 168.94335034547 -78.27443758394
# 168.95280246816 -78.26453038843 ... 168.95293308616 -78.26453774668
# 168.91062724736 -78.28217641970 ... 168.91081566310 -78.28218229582
# 168.82617508438 -78.28535068083 ... 168.82623811347 -78.28536424900
# 168.81969733744 -78.28436327808 ... 168.81986175418 -78.28437722069
#             ...             ... ...             ...             ...
# ...

# %%
Simbad

# %%
gaia_id=result[0]["Source"][cond_gaia]
gaia_id
# Out:
# <MaskedColumn name='Source' dtype='int64' description='Unique source identifier (unique within a particular Data Release) (source_id)' length=22453>
# 5199968651033259392
# 5199968651033259648
# 5199968655331608704
# 5199968685392997888
# 5199968689691347840
# 5200343863675067264
# 5200343893736913280
# 5200343966754278400
# 5200343996816090752
# 5200343996816090880
# 5200343996816092032
# 5200344001110109440
#                 ...
# 5201525937455378816
# 5201525937455386880
# 5201525971815115904
# 5201525971815118080
# 5201526040534597376
# 5201526044834190720
# 5201526182273441536
# 5201526182273441664
# 5201526216629987840
# 5201526216629988224
# 5201526246693049984
# 5201526727729373312

# %%
all_ids=[]
for item in gaia_id:
    result_table = Simbad.query_objectids("Gaia DR3 %s"%item)#5201179389431267584

    print(result_table)
    if type(result_table) == None:
        print("skip")
    else:
        all_ids.append(result_table)
# Out:
# None
# None
# None
# None
# None
#              ID
# ----------------------------
# Gaia DR3 5200343863675067264
#        GES J11154638-7816279
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
#              ID
# ----------------------------
#        GES J11171216-7809366
# Gaia DR3 5200345822180215680
#    WISEA J111712.13-780936.4
#                TIC 395092169
#        RAVE J111712.2-780937
#      2MASS J11171216-7809366
#              UCAC2    458014
#               UCAC3 24-23330
#             UCAC4 060-010575
# ...

# %%
all_ids

# %%
#find if the id has WDS 
#element.split
all_nonempty_ids=[]
for item in all_ids:
    if type(item) == None:
        print(item)
    else:
        all_nonempty_ids.append(item)

# %%
len(all_nonempty_ids)

# %%
for i in range(len(all_nonempty_ids)):
    for item in all_nonempty_ids[i]:
        #print(item)
        if "WDS" in str(item):
            print("Star with this ID is crossmatched with Gaia and WDS")
            print(all_nonempty_ids[i])
        else:
            print("no WDS found")
# Out:
# no WDS found
# no WDS found
# no WDS found
# no WDS found
# no WDS found
# no WDS found
# no WDS found
# no WDS found
# no WDS found
# no WDS found
# no WDS found
# no WDS found
# no WDS found
# no WDS found
# no WDS found
# no WDS found
# no WDS found
# no WDS found
# no WDS found
# no WDS found
# no WDS found
# no WDS found
# no WDS found
# no WDS found
# no WDS found
# no WDS found
# no WDS found
# no WDS found
# no WDS found
# no WDS found
# no WDS found
# no WDS found
# no WDS found
# no WDS found
# no WDS found
# no WDS found
# no WDS found
# no WDS found
# no WDS found
# no WDS found
# no WDS found
# no WDS found
# no WDS found
# no WDS found
# no WDS found
# no WDS found
# no WDS found
# no WDS found
# no WDS found
# no WDS found
# no WDS found
# no WDS found
# no WDS found
# no WDS found
# no WDS found
# no WDS found
# no WDS found
# no WDS found
# no WDS found
# no WDS found
# no WDS found
# no WDS found
# no WDS found
# no WDS found
# no WDS found
# no WDS found
# ...

# %%
result_table = Simbad.query_objectids("WDS J11024-7734A")

print(result_table)

# %%
result_table = Simbad.query_objectids("CS cha")
print(result_table)

# %%
print(result[0][result[0]["WDS"]=="11024-7734"])

# %%
print(result[1][result[1]["RUWE"]<1.2][result[1]["Source"]=="5201179389431267584"]) #DR3 5201179389431267584
